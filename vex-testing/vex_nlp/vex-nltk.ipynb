# %%
import os
import nltk
import pprint

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so

# Read in a plain text file
with open(os.path.join("data", "final-text-dataset.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# The VEX V5 Leaderboard is a fun and interactive tool that can be used to display and document student performance in the STEM Labs, keeping students engaged with each other. Using the VEX V5 Leaderboard with Your Classroom The VEX V5 STEM Lab are focused around Rethink challenges. Challenges promote collaboration and naturally motivate students to improve their robots, their strategy, and their code. The VEX V5 Leaderboard is designed to help facilitate these challenges by providing an interactive tool for educators to use to present and record challenge data. Display the leaderboard throughout your challenge to show team scores and ranking, making it easy for students to visualize overall team performance throughout the challenge. Customizing the Leaderboard for Your Challenge The steps below outline how to add information and customize the leaderboard for your classroom challenge. Access the VEX V5 Leaderboard To access the VEX V5 Leaderboard, go to https://education.vex.com/leader
# ...

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
josh = tokenizer.tokenize(text)

# %%
len(josh)
#print(josh)
# Out:
# 54677

# %%
pprint.pprint(josh)
# Out:
# ['The',
#  'VEX',
#  'V5',
#  'Leaderboard',
#  'is',
#  'a',
#  'fun',
#  'and',
#  'interactive',
#  'tool',
#  'that',
#  'can',
#  'be',
#  'used',
#  'to',
#  'display',
#  'and',
#  'document',
#  'student',
#  'performance',
#  'in',
#  'the',
#  'STEM',
#  'Labs',
#  'keeping',
#  'students',
#  'engaged',
#  'with',
#  'each',
#  'other',
#  'Using',
#  'the',
#  'VEX',
#  'V5',
#  'Leaderboard',
#  'with',
#  'Your',
#  'Classroom',
#  'The',
#  'VEX',
#  'V5',
#  'STEM',
#  'Lab',
#  'are',
#  'focused',
#  'around',
#  'Rethink',
#  'challenges',
#  'Challenges',
#  'promote',
#  'collaboration',
#  'and',
#  'naturally',
#  'motivate',
#  'students',
#  'to',
#  'improve',
#  'their',
#  'robots',
#  'their',
#  'strategy',
#  'and',
#  'their',
#  'code',
#  'The',
#  'VEX',
#  'V5',
#  'Leaderboard',
#  'is',
#  'designed',
#  'to',
#  'help',
#  'facilitate',
#  'these',
#  'challenges',
#  'by',
#  'providing',
#  'an',
#  'interactive',
#  'tool',
#  'for',
# ...

# %%
# removed all punctuation
token_words = [w.lower() for w in josh if w.isalpha() if len(w) >= 2]

# %%
#sentences = nltk.sent_tokenize(text)
len(token_words)
# Out:
# 52091

# %%
pprint.pprint(token_words)
# Out:
# ['the',
#  'vex',
#  'leaderboard',
#  'is',
#  'fun',
#  'and',
#  'interactive',
#  'tool',
#  'that',
#  'can',
#  'be',
#  'used',
#  'to',
#  'display',
#  'and',
#  'document',
#  'student',
#  'performance',
#  'in',
#  'the',
#  'stem',
#  'labs',
#  'keeping',
#  'students',
#  'engaged',
#  'with',
#  'each',
#  'other',
#  'using',
#  'the',
#  'vex',
#  'leaderboard',
#  'with',
#  'your',
#  'classroom',
#  'the',
#  'vex',
#  'stem',
#  'lab',
#  'are',
#  'focused',
#  'around',
#  'rethink',
#  'challenges',
#  'challenges',
#  'promote',
#  'collaboration',
#  'and',
#  'naturally',
#  'motivate',
#  'students',
#  'to',
#  'improve',
#  'their',
#  'robots',
#  'their',
#  'strategy',
#  'and',
#  'their',
#  'code',
#  'the',
#  'vex',
#  'leaderboard',
#  'is',
#  'designed',
#  'to',
#  'help',
#  'facilitate',
#  'these',
#  'challenges',
#  'by',
#  'providing',
#  'an',
#  'interactive',
#  'tool',
#  'for',
#  'educators',
#  'to',
#  'use',
#  'to',
# ...

# %%
#tokens = nltk.word_tokenize(text)

# %%
# removed all punctuation
token_words = [w.lower() for w in words if w.isalpha()] #if len(w) > 3]

# %%
from nltk.corpus import stopwords
 
nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
#example_sent = token_words

stop_words = set(stopwords.words('english'))
v = ["IQ", "iq", "123", "GO", "VEX", "lab", "v5"]
#word_tokens = word_tokenize(example_sent)
# converts the words in word_tokens to lower case and then checks whether
#they are present in stop_words or not

filtered_sentence = [w for w in token_words if not w.lower() in stop_words and len(w) >= 2]
#with no lower case conversion
#filtered_sentence = []

#for w in token_words:
#	if w not in token_words:
#		filtered_sentence.append(w)


#print(word_tokens)
#print(filtered_sentence)
type(filtered_sentence)
len(filtered_sentence)
#pprint.pprint(filtered_sentence)
# Out:
# 23781

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/joshstudl/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/joshstudl/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/joshstudl/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
freq = nltk.FreqDist(filtered_sentence)

# Only keep words that appear more than once
#processed_corpus = [[token for token in text if frequency[token] > 1] for text in texts]
#pprint.pprint(processed_corpus)

# 10 most common words
pprint.pprint(freq.most_common(20))
# Out:
# [('project', 394),
#  ('sensor', 385),
#  ('vexcode', 359),
#  ('vex', 311),
#  ('using', 283),
#  ('robot', 248),
#  ('select', 232),
#  ('exp', 219),
#  ('help', 198),
#  ('see', 196),
#  ('use', 192),
#  ('example', 168),
#  ('learn', 164),
#  ('vr', 164),
#  ('used', 156),
#  ('view', 153),
#  ('iq', 145),
#  ('button', 144),
#  ('students', 143),
#  ('field', 141)]

# %%
#Stemming
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()
string_for_stemming = freq

stemmed_words = [stemmer.stem(word) for word in freq]

# %%
stemmed_words
# Out:
# ['project',
#  'sensor',
#  'vexcod',
#  'vex',
#  'use',
#  'robot',
#  'select',
#  'exp',
#  'help',
#  'see',
#  'use',
#  'exampl',
#  'learn',
#  'vr',
#  'use',
#  'view',
#  'iq',
#  'button',
#  'student',
#  'field',
#  'inform',
#  'block',
#  'articl',
#  'brain',
#  'one',
#  'data',
#  'open',
#  'also',
#  'may',
#  'check',
#  'playground',
#  'control',
#  'vrc',
#  'virtual',
#  'skill',
#  'score',
#  'code',
#  'code',
#  'sensor',
#  'drive',
#  'stem',
#  'go',
#  'make',
#  'tri',
#  'flex',
#  'want',
#  'block',
#  'learn',
#  'differ',
#  'move',
#  'competit',
#  'activ',
#  'switch',
#  'devic',
#  'arm',
#  'time',
#  'project',
#  'step',
#  'build',
#  'like',
#  'sure',
#  'run',
#  'new',
#  'command',
#  'start',
#  'batteri',
#  'follow',
#  'window',
#  'order',
#  'shown',
#  'lab',
#  'profession',
#  'full',
#  'motor',
#  'step',
#  'object',
#  'color',
#  'ensur',
#  'chang',
#  'valu',
#  'set',
#  'game',
#  'activ',
#  'within',
# ...

# %%
for z in freq:
    print(z, " : ", stemmer.stem(z))
# Out:
# project  :  project
# sensor  :  sensor
# vexcode  :  vexcod
# vex  :  vex
# using  :  use
# robot  :  robot
# select  :  select
# exp  :  exp
# help  :  help
# see  :  see
# use  :  use
# example  :  exampl
# learn  :  learn
# vr  :  vr
# used  :  use
# view  :  view
# iq  :  iq
# button  :  button
# students  :  student
# field  :  field
# information  :  inform
# blocks  :  block
# article  :  articl
# brain  :  brain
# one  :  one
# data  :  data
# open  :  open
# also  :  also
# may  :  may
# check  :  check
# playground  :  playground
# controller  :  control
# vrc  :  vrc
# virtual  :  virtual
# skills  :  skill
# score  :  score
# coding  :  code
# code  :  code
# sensors  :  sensor
# drive  :  drive
# stem  :  stem
# go  :  go
# make  :  make
# try  :  tri
# flex  :  flex
# want  :  want
# block  :  block
# learning  :  learn
# different  :  differ
# move  :  move
# competition  :  competit
# activity  :  activ
# switch  :  switch
# device  :  devic
# arm  :  arm
# ...

# %%
# import these modules

import nltk
nltk.download('omw-1.4')

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

string_for_lemming = freq

for j in freq:
    print(j, " : ", lemmatizer.lemmatize(j))

# a denotes adjective in "pos"
#print("better :", lemmatizer.lemmatize("better", pos ="a"))
# Out:
# project  :  project
# sensor  :  sensor
# vexcode  :  vexcode
# vex  :  vex
# using  :  using
# robot  :  robot
# select  :  select
# exp  :  exp
# help  :  help
# see  :  see
# use  :  use
# example  :  example
# learn  :  learn
# vr  :  vr
# used  :  used
# view  :  view
# iq  :  iq
# button  :  button
# students  :  student
# field  :  field
# information  :  information
# blocks  :  block
# article  :  article
# brain  :  brain
# one  :  one
# data  :  data
# open  :  open
# also  :  also
# may  :  may
# check  :  check
# playground  :  playground
# controller  :  controller
# vrc  :  vrc
# virtual  :  virtual
# skills  :  skill
# score  :  score
# coding  :  coding
# code  :  code
# sensors  :  sensor
# drive  :  drive
# stem  :  stem
# go  :  go
# make  :  make
# try  :  try
# flex  :  flex
# want  :  want
# block  :  block
# learning  :  learning
# different  :  different
# move  :  move
# competition  :  competition
# activity  :  activity
# switch  :  switch
# ...

# %%
import gensim
from gensim import corpora

# %%
from collections import defaultdict

# remove common words and tokenize
stoplist = set('for a of the and to in'.split())
texts = [
    [word for word in document.lower().split() if word not in stoplist]
    for document in documents
]

# remove words that appear only once
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [
    [token for token in text if frequency[token] > 1]
    for text in texts
]

pprint(texts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[213], line 7
#       3 # remove common words and tokenize
#       4 stoplist = set('for a of the and to in'.split())
#       5 texts = [
#       6     [word for word in document.lower().split() if word not in stoplist]
# ----> 7     for document in documents
#       8 ]
#      10 # remove words that appear only once
#      11 frequency = defaultdict(int)
#
# NameError: name 'documents' is not defined

# %%
from nltk.test.gensim_fixt import setup_module
setup_module()

# %%
# Create a set of frequent words
stoplist = set('for a of the and to in'.split(' '))
# Lowercase each document, split it by white space and filter out stopwords
texts = [[word for word in document.lower().split() if word not in stoplist]
         for document in text_corpus]

# Count word frequencies
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

# Only keep words that appear more than once
processed_corpus = [[token for token in text if frequency[token] > 1] for text in texts]
pprint.pprint(processed_corpus)

# %%
model = gensim.models.Word2Vec(vexkbtext)
train_set = model
model = gensim.models.Word2Vec.load('vexkbtext')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[108], line 3
#       1 model = gensim.models.Word2Vec(vexkbtext)
#       2 train_set = model
# ----> 3 model = gensim.models.Word2Vec.load('vexkbtext')
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/gensim/models/word2vec.py:1942, in Word2Vec.load(cls, rethrow, *args, **kwargs)
#    1923 """Load a previously saved :class:`~gensim.models.word2vec.Word2Vec` model.
#    1924
#    1925 See Also
#    (...)
#    1939
#    1940 """
#    1941 try:
# -> 1942     model = super(Word2Vec, cls).load(*args, **kwargs)
#    1943     if not isinstance(model, Word2Vec):
#    1944         rethrow = True
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/gensim/utils.py:486, in SaveLoad.load(cls, fname, mmap)
#     482 logger.info("loading %s object from %s", cls.__name__, fname)
# ...

# %%
new_model = gensim.models.Word2Vec.load('vexkb.embedding')

# %%
len(new_model.wv['vex'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 len(new_model.wv['vex'])
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/gensim/models/keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/gensim/models/keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# ...

# %%
# Frequency of words
dist = FreqDist(text7)
len(dist)
# Out:
# 12408

# %%
vocab1 = list(dist.keys())
vocab1[:10]
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', 'will', 'join', 'the', 'board']

# %%
dist['Vinken']
# Out:
# 2

# %%
freqwords = [w for w in vocab1 if len(w) > 5 and dist[w] > 100]
freqwords
# Out:
# ['billion',
#  'company',
#  'president',
#  'because',
#  'market',
#  'million',
#  'shares',
#  'trading',
#  'program']

# %%
# different forms of the same "word"
input1 = 'List listed lists listing listings'
words1 = input1.lower().split(' ')
words1
# Out:
# ['list', 'listed', 'lists', 'listing', 'listings']

# %%
porter = nltk.PorterStemmer()
[porter.stem(t) for t in words1]
# Out:
# ['list', 'list', 'list', 'list', 'list']

# %%
# tokenization
text11 = "Children shouldn't drink a sugary drink before bed."
text11.split(' ')
# Out:
# ['Children', "shouldn't", 'drink', 'a', 'sugary', 'drink', 'before', 'bed.']

# %%
nltk.word_tokenize(text11)
# Out:
# ['Children',
#  'should',
#  "n't",
#  'drink',
#  'a',
#  'sugary',
#  'drink',
#  'before',
#  'bed',
#  '.']

# %%
# sentence splitting
text12 = 'This is the first sentence. A gallon of milk in the U.S. costs $2.99. Is this the third sentence? Yes, it is!'
sentences = nltk.sent_tokenize(text12)
len(sentences)
# Out:
# 4

# %%
sentences
# Out:
# ['This is the first sentence.',
#  'A gallon of milk in the U.S. costs $2.99.',
#  'Is this the third sentence?',
#  'Yes, it is!']
